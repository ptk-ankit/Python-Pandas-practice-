# %%
import pandas as pd

Terrorism_data=pd.read_csv("terrorismData.csv")
Terrorism_data
# Out:
#         Year  Month  Day             Country            State  \
# 0       1970      7    2  Dominican Republic              NaN
# 1       1970      0    0              Mexico          Federal
# 2       1970      1    0         Philippines           Tarlac
# 3       1970      1    0              Greece           Attica
# 4       1970      1    0               Japan          Fukouka
# ...      ...    ...  ...                 ...              ...
# 181686  2017     12   31             Somalia  Middle Shebelle
# 181687  2017     12   31               Syria         Lattakia
# 181688  2017     12   31         Philippines      Maguindanao
# 181689  2017     12   31               India          Manipur
# 181690  2017     12   31         Philippines      Maguindanao
#
#                              Region           City   Latitude   Longitude  \
# 0       Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# ...

# %%
# Here we are making a copy aof a file using "Copy" keyword
# we can use Head for how many result we want,number of rows to be returned
df=Terrorism_data.copy()
Terrorism_data.head(5)
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   Latitude   Longitude                      AttackType  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    Killed  Wounded                   Target Summary  \
# ...

# %%
print(Terrorism_data.shape)
# Out:
# (181691, 17)

# %%
print(Terrorism_data.describe())
# Out:
#                 Year          Month            Day       Latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           Longitude         Killed        Wounded
# count  1.771340e+05  171378.000000  165380.000000
# mean  -4.586957e+02       2.403272       3.167668
# std    2.047790e+05      11.545741      35.949392
# min   -8.618590e+07       0.000000       0.000000
# 25%    4.545640e+00       0.000000       0.000000
# 50%    4.324651e+01       0.000000       0.000000
# ...

# %%
# It give the alll info regarding data frame
print(Terrorism_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 17 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   Day          181691 non-null  int64
#  3   Country      181691 non-null  object
#  4   State        181270 non-null  object
#  5   Region       181691 non-null  object
#  6   City         181256 non-null  object
#  7   Latitude     177135 non-null  float64
#  8   Longitude    177134 non-null  float64
#  9   AttackType   181691 non-null  object
#  10  Killed       171378 non-null  float64
#  11  Wounded      165380 non-null  float64
#  12  Target       181053 non-null  object
#  13  Summary      115562 non-null  object
#  14  Group        181691 non-null  object
#  15  Target_type  181691 non-null  object
#  16  Weapon_type  181691 non-null  object
# dtypes: float64(4), int64(3), object(10)
# ...

# %%
# Slicing
# we cn get desired row and column using 'iloc'
df=Terrorism_data.iloc[1:15, 1:4]
df
# Out:
#     Month  Day        Country
# 1       0    0         Mexico
# 2       1    0    Philippines
# 3       1    0         Greece
# 4       1    0          Japan
# 5       1    1  United States
# 6       1    2        Uruguay
# 7       1    2  United States
# 8       1    2  United States
# 9       1    3  United States
# 10      1    1  United States
# 11      1    6  United States
# 12      1    8          Italy
# 13      1    9  United States
# 14      1    9  United States

# %%
#it is give the total sum of null values in column
df=Terrorism_data.isnull().sum()
df
# Out:
# Year               0
# Month              0
# Day                0
# Country            0
# State            421
# Region             0
# City             435
# Latitude        4556
# Longitude       4557
# AttackType         0
# Killed         10313
# Wounded        16311
# Target           638
# Summary        66129
# Group              0
# Target_type        0
# Weapon_type        0
# dtype: int64

# %%
# show null values
# True- Null
# False- not Null
df=Terrorism_data.isna()
df
# Out:
#          Year  Month    Day  Country  State  Region   City  Latitude  \
# 0       False  False  False    False   True   False  False     False
# 1       False  False  False    False  False   False  False     False
# 2       False  False  False    False  False   False  False     False
# 3       False  False  False    False  False   False  False     False
# 4       False  False  False    False  False   False  False     False
# ...       ...    ...    ...      ...    ...     ...    ...       ...
# 181686  False  False  False    False  False   False  False     False
# 181687  False  False  False    False  False   False  False     False
# 181688  False  False  False    False  False   False  False     False
# 181689  False  False  False    False  False   False  False     False
# 181690  False  False  False    False  False   False  False     False
#
#         Longitude  AttackType  Killed  Wounded  Target  Summary  Group  \
# ...

# %%
#df.drop(0,inplace=True)
df.head(5)
# Out:
#    Month  Day        Country
# 1      0    0         Mexico
# 2      1    0    Philippines
# 3      1    0         Greece
# 4      1    0          Japan
# 5      1    1  United States

# %%
a=df.drop(1)
a.head(5)
# Out:
#    Month  Day        Country
# 2      1    0    Philippines
# 3      1    0         Greece
# 4      1    0          Japan
# 5      1    1  United States
# 6      1    2        Uruguay

# %% [markdown]
# ### You can clearly seen that Row 1st(at Index 1) has been removed

# %%
# Using Inplace, we do not need of copy the dataframe to remove row
df.drop(1,inplace=True)
df.head(5)
# Out:
#    Year  Month  Day        Country       State          Region        City  \
# 2  1970      1    0    Philippines      Tarlac  Southeast Asia     Unknown
# 3  1970      1    0         Greece      Attica  Western Europe      Athens
# 4  1970      1    0          Japan     Fukouka       East Asia     Fukouka
# 5  1970      1    1  United States    Illinois   North America       Cairo
# 6  1970      1    2        Uruguay  Montevideo   South America  Montevideo
#
#     Latitude   Longitude                      AttackType  Killed  Wounded  \
# 2  15.478598  120.599741                   Assassination     1.0      0.0
# 3  37.997490   23.762728               Bombing/Explosion     NaN      NaN
# 4  33.580412  130.396361  Facility/Infrastructure Attack     NaN      NaN
# 5  37.005105  -89.176269                   Armed Assault     0.0      0.0
# 6 -34.891151  -56.187214                   Assassination     0.0      0.0
#
#                                               Target  \
# ...

# %%
df.Year>2000,df.Latitude>35
# Out:
# (2         False
#  3         False
#  4         False
#  5         False
#  6         False
#            ...
#  181686     True
#  181687     True
#  181688     True
#  181689     True
#  181690     True
#  Name: Year, Length: 181689, dtype: bool,
#  2         False
#  3          True
#  4         False
#  5          True
#  6         False
#            ...
#  181686    False
#  181687     True
#  181688    False
#  181689    False
#  181690    False
#  Name: Latitude, Length: 181689, dtype: bool)

# %%
# If I want only those rows where Year is greater than 2000

df[df.Year>2000]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4644\2662557908.py in ?()
#       1 # If I want only those rows where Year is greater than 2000
#       2
# ----> 3 df[df.Year>2000]
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Year'

# %%
# If I want only 5 rows of upper condition

df[df.Year>2000].head(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4644\868777418.py in ?()
#       1 # If I want only 5 rows of upper condition
#       2
# ----> 3 df[df.Year>2000].head(5)
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Year'

# %%
df[df.Country=='India']
# Out:
#         Year  Month  Day Country              State      Region  \
# 1186    1972      2   22   India              Delhi  South Asia
# 2764    1975      1    2   India              Bihar  South Asia
# 3857    1976      5   26   India              Delhi  South Asia
# 5327    1977      9   28   India        Maharashtra  South Asia
# 7337    1979      1   13   India              Assam  South Asia
# ...      ...    ...  ...     ...                ...         ...
# 181663  2017     12   30   India             Kerala  South Asia
# 181665  2017     12   30   India       Chhattisgarh  South Asia
# 181672  2017     12   31   India  Jammu and Kashmir  South Asia
# 181684  2017     12   31   India              Assam  South Asia
# 181689  2017     12   31   India            Manipur  South Asia
#
#                  City   Latitude  Longitude                      AttackType  \
# 1186        New Delhi  28.585836  77.153336                       Hijacking
# ...

# %%
df[df.Country=='India'].describe()
# Out:
#                Year         Month           Day      Latitude     Longitude  \
# count  11960.000000  11960.000000  11960.000000  11801.000000  11801.000000
# mean    2006.248411      6.439047     15.624415     25.947957     82.788312
# std       10.096520      3.323835      8.778965      5.674857      7.039908
# min     1972.000000      1.000000      0.000000      8.169375     68.775724
# 25%     1999.000000      4.000000      8.000000     22.585272     75.341218
# 50%     2010.000000      6.000000     15.000000     25.272700     81.866144
# 75%     2014.000000      9.000000     23.000000     31.147131     88.352341
# max     2017.000000     12.000000     31.000000     34.655639     96.644737
#
#              Killed       Wounded
# count  11740.000000  11506.000000
# mean       1.647445      2.518686
# std        4.681342     11.344047
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        1.000000      1.000000
# ...

# %% [markdown]
# ## 1. Differences between loc and iloc
# The main distinction between loc and iloc is:
#
# - loc is label-based, which means that you have to specify rows and columns based on their row and column labels. <br>
# - iloc is integer position-based, so you have to specify rows and columns by their integer position values (0-based integer position).

# %%
# if I want How many peoples killed on day wise in Mumbai City

df.loc[(df.Country=='India')&(df.Killed) & (df.City=='Bombay'),['Day','Killed','City']]
# Out:
#        Day  Killed    City
# 23860   27     1.0  Bombay
# 44072   20     3.0  Bombay
# 44769    4     3.0  Bombay
# 44774    4     3.0  Bombay
# 46169   19     6.0  Bombay
# 46170   19     1.0  Bombay
# 46171   19     6.0  Bombay
# 48914    3     1.0  Bombay
# 50124   10     1.0  Bombay
# 50389    4     2.0  Bombay
# 52552   13     1.0  Bombay
# 54416    8   115.0  Bombay
# 57123   25     2.0  Bombay

# %% [markdown]
# ## 6. `loc` and `iloc` are interchangeable when labels are 0-based integers

# %%
# if I want How many peoples killed on day wise in Mumbai City with total columns

df.loc[(df.Country=='India')&(df.Killed) & (df.City=='Bombay'),:]
# Out:
#        Year  Month  Day Country        State      Region    City   Latitude  \
# 23860  1984     11   27   India  Maharashtra  South Asia  Bombay  19.075984
# 44072  1990      9   20   India  Maharashtra  South Asia  Bombay  19.075984
# 44769  1990     12    4   India  Maharashtra  South Asia  Bombay  19.075984
# 44774  1990     12    4   India  Maharashtra  South Asia  Bombay  19.075984
# 46169  1991      4   19   India  Maharashtra  South Asia  Bombay  19.075984
# 46170  1991      4   19   India  Maharashtra  South Asia  Bombay  19.075984
# 46171  1991      4   19   India  Maharashtra  South Asia  Bombay  19.075984
# 48914  1991     11    3   India  Maharashtra  South Asia  Bombay  19.075984
# 50124  1992      2   10   India  Maharashtra  South Asia  Bombay  19.075984
# 50389  1992      3    4   India  Maharashtra  South Asia  Bombay  19.075984
# 52552  1992      8   13   India  Maharashtra  South Asia  Bombay  19.075984
# ...

# %%
df.loc[(df.Country=='India')&(df.Killed) & (df.City=='Bombay'), 5:10]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 df.loc[(df.Country=='India')&(df.Killed) & (df.City=='Bombay'), 5:10]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1377, in _LocIndexer._getitem_tuple(self, tup)
#    1374 if self._multi_take_opportunity(tup):
#    1375     return self._multi_take(tup)
# -> 1377 return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
df.iloc[4, [1,2]]
# Out:
# Month    1
# Day      2
# Name: 6, dtype: object

# %%
# the equivalent iloc statement
rows = [3, 4]
cols = [1, 2]
df.iloc[rows, cols]
# Out:
#    Month  Day
# 5      1    1
# 6      1    2

# %% [markdown]
# ## Reset Index after deleted some rows

# %%
df.reset_index()
# Out:
#          index  Year  Month  Day        Country            State  \
# 0            2  1970      1    0    Philippines           Tarlac
# 1            3  1970      1    0         Greece           Attica
# 2            4  1970      1    0          Japan          Fukouka
# 3            5  1970      1    1  United States         Illinois
# 4            6  1970      1    2        Uruguay       Montevideo
# ...        ...   ...    ...  ...            ...              ...
# 181684  181686  2017     12   31        Somalia  Middle Shebelle
# 181685  181687  2017     12   31          Syria         Lattakia
# 181686  181688  2017     12   31    Philippines      Maguindanao
# 181687  181689  2017     12   31          India          Manipur
# 181688  181690  2017     12   31    Philippines      Maguindanao
#
#                             Region           City   Latitude   Longitude  \
# 0                   Southeast Asia        Unknown  15.478598  120.599741
# ...

# %%
# If we use true inside reset_index than it will remove Index column that made new 
df.reset_index(drop=True)
# Out:
#         Year  Month  Day        Country            State  \
# 0       1970      1    0    Philippines           Tarlac
# 1       1970      1    0         Greece           Attica
# 2       1970      1    0          Japan          Fukouka
# 3       1970      1    1  United States         Illinois
# 4       1970      1    2        Uruguay       Montevideo
# ...      ...    ...  ...            ...              ...
# 181684  2017     12   31        Somalia  Middle Shebelle
# 181685  2017     12   31          Syria         Lattakia
# 181686  2017     12   31    Philippines      Maguindanao
# 181687  2017     12   31          India          Manipur
# 181688  2017     12   31    Philippines      Maguindanao
#
#                             Region           City   Latitude   Longitude  \
# 0                   Southeast Asia        Unknown  15.478598  120.599741
# 1                   Western Europe         Athens  37.997490   23.762728
# ...

# %% [markdown]
# ## How to delete Column
# There is 2 way
# - we can use 'del' command like- **del df['Column_name']**
# - other we can use drop function<br>
#           - df.drop('Column_name',axis=1,inplace=True/False

# %%
del df['Month']

# %%
df.describe()
# Out:
#                  Day       Latitude     Longitude         Killed  \
# count  181689.000000  177133.000000  1.771320e+05  171376.000000
# mean       15.505804      23.498395 -4.586999e+02       2.403295
# std         8.813961      18.569341  2.047801e+05      11.545806
# min         0.000000     -53.154613 -8.618590e+07       0.000000
# 25%         8.000000      11.510046  4.547954e+00       0.000000
# 50%        15.000000      31.467463  4.324651e+01       0.000000
# 75%        23.000000      34.685087  6.871033e+01       2.000000
# max        31.000000      74.633553  1.793667e+02    1570.000000
#
#              Wounded
# count  165378.000000
# mean        3.167707
# std        35.949607
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         2.000000
# max      8191.000000

# %%
df.drop('Day',axis=1,inplace=True)

# %%
df.describe()
# Out:
#             Latitude     Longitude         Killed        Wounded
# count  177133.000000  1.771320e+05  171376.000000  165378.000000
# mean       23.498395 -4.586999e+02       2.403295       3.167707
# std        18.569341  2.047801e+05      11.545806      35.949607
# min       -53.154613 -8.618590e+07       0.000000       0.000000
# 25%        11.510046  4.547954e+00       0.000000       0.000000
# 50%        31.467463  4.324651e+01       0.000000       0.000000
# 75%        34.685087  6.871033e+01       2.000000       2.000000
# max        74.633553  1.793667e+02    1570.000000    8191.000000

# %%
# reseting again the original data
df=Terrorism_data.copy()
df.describe()
# Out:
#                 Year          Month            Day       Latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           Longitude         Killed        Wounded
# count  1.771340e+05  171378.000000  165380.000000
# mean  -4.586957e+02       2.403272       3.167668
# std    2.047790e+05      11.545741      35.949392
# min   -8.618590e+07       0.000000       0.000000
# 25%    4.545640e+00       0.000000       0.000000
# 50%    4.324651e+01       0.000000       0.000000
# ...

# %% [markdown]
# ## Handling NAN Values
#
# ###Values considered “missing”
#
# As data comes in many shapes and forms, pandas aims to be flexible with regard to handling missing data. While NaN is the default missing value marker for reasons of computational speed and convenience, we need to be able to easily detect this value with data of different types: floating point, integer, boolean, and general object. In many cases, however, the Python None will arise and we wish to also consider that “missing” or “not available” or “NA”.
#
# To make detecting missing values easier (and across different array dtypes), pandas provides the isna() and notna() functions, which are also methods on Series and DataFrame objects.
#
# Because NaN is a float, a column of integers with even one missing values is cast to floating-point dtype
#
# NaN values can create inaccuracies in our estimations and calculations. There are two ways we can handle NaN:
#
# we either remove them,
# or we fill them.
#
#
#
#
#
#
# Our current data does not have any NaN values, so we will create some.

# %%
#the first row will give the count that mean how many row have NAN value we can find 
df.describe()
# Out:
#                 Year          Month            Day       Latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           Longitude         Killed        Wounded
# count  1.771340e+05  171378.000000  165380.000000
# mean  -4.586957e+02       2.403272       3.167668
# std    2.047790e+05      11.545741      35.949392
# min   -8.618590e+07       0.000000       0.000000
# 25%    4.545640e+00       0.000000       0.000000
# 50%    4.324651e+01       0.000000       0.000000
# ...

# %% [markdown]
# ### dropna() : This will remove the row or column entries with NaN values.

# %%
a=df.dropna()
a.describe()
# Out:
#                 Year          Month            Day       Latitude  \
# count  105570.000000  105570.000000  105570.000000  105570.000000
# mean     2011.547154       6.470853      15.573259      27.036139
# std         5.894601       3.381289       8.819966      13.272554
# min      1970.000000       1.000000       0.000000     -42.884049
# 25%      2010.000000       4.000000       8.000000      18.527716
# 50%      2013.000000       6.000000      15.000000      32.777344
# 75%      2015.000000       9.000000      23.000000      34.397052
# max      2017.000000      12.000000      31.000000      74.633553
#
#            Longitude         Killed        Wounded
# count  105570.000000  105570.000000  105570.000000
# mean       49.918459       2.132187       3.775874
# std        39.890091       9.760282      40.530896
# min      -157.858333       0.000000       0.000000
# 25%        37.802850       0.000000       0.000000
# 50%        44.660528       1.000000       0.000000
# ...

# %% [markdown]
# ## fillna() :
# #### You can also fill NaN using a dict or Series that is alignable. The labels of the dict or index of the Series must match the columns of the frame you wish to fill.
#
# #### Generally we fill the NaN values with the mean, but depending on the type of data, and your own analysis, you may decide to will NaN in some other way.

# %%
df.Killed.fillna(df.Killed.mean(),inplace=True)
df.Wounded.fillna(df.Wounded.mean(),inplace=True)
df.describe()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_14544\1458681813.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Wounded.fillna(df.Wounded.mean(),inplace=True)
#                 Year          Month            Day       Latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# ...

# %%
df.describe()
# Out:
#                 Year          Month            Day       Latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           Longitude         Killed        Wounded
# count  1.771340e+05  181691.000000  181691.000000
# mean  -4.586957e+02       2.403272       3.167668
# std    2.047790e+05      11.213277      34.297796
# min   -8.618590e+07       0.000000       0.000000
# 25%    4.545640e+00       0.000000       0.000000
# 50%    4.324651e+01       1.000000       0.000000
# ...

# %% [markdown]
# ### **Handling Strings in Data**

# %% [markdown]
# Our algorithms can make calculations over numerical data. String data is very hard to compute quantitaviely.
#
# It wont make sense to ignore string data. For example, if a dataset is to evaluate shopping habits, and we have a column for gender with categories as 'male' and 'female', we cannot just ignore this, as the habits of both the gender will be very different from each other.
#
# So, to handle such cases, we convert the string data to numerical data.

# %%
def func(s):
  if s == 'Male':
    return 0
  else:
    return 1

df['Sex'] = df.Gender.apply(func)
del df['Gender']
df

# %% [markdown]
# ### Plotting the graphs

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

Terrorism_data=pd.read_csv("terrorismData.csv")
df=Terrorism_data.copy()
# print(Terrorism_data.head())
# print(Terrorism_data.columns)
# print(df['Latitude'].dtype)
pd.plotting.andrews_curves(df,'Year')  
plt.title("Andrews Curves Plot")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 10
#       6 df=Terrorism_data.copy()
#       7 # print(Terrorism_data.head())
#       8 # print(Terrorism_data.columns)
#       9 # print(df['Latitude'].dtype)
# ---> 10 pd.plotting.andrews_curves(df,'Year')
#      11 plt.title("Andrews Curves Plot")
#      12 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\plotting\_misc.py:380, in andrews_curves(frame, class_column, ax, samples, color, colormap, **kwargs)
#     331 """
#     332 Generate a matplotlib plot for visualizing clusters of multivariate data.
#     333
#    (...)
#     377     >>> pd.plotting.andrews_curves(df, 'Name')  # doctest: +SKIP
#     378 """
#     379 plot_backend = _get_plot_backend("matplotlib")
# --> 380 return plot_backend.andrews_curves(
#     381     frame=frame,
# ...

# %%
# It will refelect how many entries null in each column
df.isnull().sum()
# Out:
# Year               0
# Month              0
# Day                0
# Country            0
# State            421
# Region             0
# City             435
# Latitude        4556
# Longitude       4557
# AttackType         0
# Killed         10313
# Wounded        16311
# Target           638
# Summary        66129
# Group              0
# Target_type        0
# Weapon_type        0
# dtype: int64

# %%
country_killed = Terrorism_data.groupby('Country')['Killed'].sum()

# Sort the results by the number of killed in descending order
country_killed_sorted = country_killed.sort_values(by='Killed', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 4
#       1 country_killed = Terrorism_data.groupby('Country')['Killed'].sum()
#       3 # Sort the results by the number of killed in descending order
# ----> 4 country_killed_sorted = country_killed.sort_values(by='Killed', ascending=False)
#
# TypeError: Series.sort_values() got an unexpected keyword argument 'by'

# %%
import pandas as pd
df=pd.read_csv("CollegePlacements.csv")

# Your code goes here. 
#updating the data
df.iloc[194,5:6]='Placed'
df.iloc[194,6:7]=240000
print(df.iloc[194])
# Out:
# S.no                              195
# Name                     Alex Grayson
# Gender                              M
# MBA_percentage                   55.0
# Highschool_percentage           64.74
# Status                         Placed
# Salary                         240000
# Name: 194, dtype: object

# %%
df[df["Highschool_percentage"]>60].count()
# Out:
# S.no                     134
# Name                     134
# Gender                   134
# MBA_percentage           134
# Highschool_percentage    134
# Status                   134
# Salary                   134
# dtype: int64

# %%
a=df["MBA_percentage"].mean()
print(a)
# Out:
# 66.33316279069768

# %%
# Write a program to Print total number of students with atleast 60 Highschool_percentage. Also print their mean MBA_percentage. 
# The dataset is a CSV file called "CollegePlacements.csv".
# Input:
# CollegePlacements.csv(CSV file)
# Output:
# Output should be in format:
#  num mean

#  where num(integer) is total number of students and mean(float) is mean MBA_percentage of all these students.

a=df[df["Highschool_percentage"]>=60]
count=len(a)
b=a["MBA_percentage"].mean()
print(count,b)
# Out:
# 134 68.24373134328359

# %%
# Write a program to calculate total number of unplaced males with  atleast 50 MBA_percentage. 
# The dataset is a CSV file called "CollegePlacements.csv".
# Input:
# CollegePlacements.csv(CSV file)
# Output:
#  An Integer showing total number of males who meet the given condition

a=df[(df["Status"]=="Not Placed") & (df["MBA_percentage"]>=50) & (df["Gender"]=='M')]
count=len(a)
print(count)
# Out:
# 28

# %%
# Write a program to print the difference between number of unplaced and number of placed students who scored atleast 45 MBA_percentage 
# The dataset is a CSV file called "CollegePlacements.csv".
# Input:
# CollegePlacements.csv(CSV file)
# Output:
#  An Integer showing the difference

a=df[(df['Status']=='Not Placed') & (df["MBA_percentage"]>=45)]
b=df[(df['Status']=='Placed') & (df["MBA_percentage"]>=45)]
print(len(b)-len(a))
# Out:
# 89

# %%
# In the given dataset, print the total number of rows where the value of age is null.

# Output Format

#   the number of rows where the age value is null.

import numpy as np
import pandas as pd

data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(data, index=labels)
a=df['age'].isnull().sum()
#b=(df['a']==True).count()
#print(df['a'])
print(a)
# Out:
# 2
